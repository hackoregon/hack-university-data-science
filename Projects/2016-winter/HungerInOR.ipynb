# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hunger_2013 = pd.read_csv("SNAP_2013.csv", skiprows=[1])

# %%
header_snap_mapping={"GEO.display-label":"oregon_county",
                     "HC01_EST_VC01":"total_households", 
                     "HC02_EST_VC01":"total_households_receiving_snap",
                     "HC03_EST_VC01":"total_households_not_receiving_snap",
                     "HC01_EST_VC02":"one_or_more_over_60",
                     "HC02_EST_VC02":"one_or_more_over_60_receiving_snap",
                     "HC03_EST_VC02":"one_or_more_over_60_not_receiving_snap",
                     "HC01_EST_VC03":"with_children_under_18",
                     "HC02_EST_VC03":"with_children_under_18_receiving_snap",
                     "HC03_EST_VC03":"with_children_under_18_not_receiving_snap",
                     "HC01_EST_VC06":"below_poverty_level",
                     "HC02_EST_VC06":"below_poverty_level_receiving_snap",
                     "HC03_EST_VC06":"below_poverty_level_not_receiving_snap",
                     "HC01_EST_VC25":"household_median_income",
                     "HC02_EST_VC25":"household_median_income_receiving_snap",
                     "HC03_EST_VC25":"household_median_income_not_receiving_snap",
                     "AH_1":"total_one_or_more_over_60_receiving_snap",
                     "AH_2":"total_food_insecurity",
                     "AH_3":"total_with_children_under_18_receiving_snap",
                     "AH_4":"percent_food_insecurity",
                     "AH_5":"percent_receiving_SNAP"
                    }

# %%
hunger_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 21 columns):
# GEO.display-label    36 non-null object
# HC01_EST_VC01        36 non-null int64
# HC02_EST_VC01        36 non-null int64
# HC03_EST_VC01        36 non-null int64
# HC01_EST_VC02        36 non-null float64
# HC02_EST_VC02        36 non-null float64
# HC03_EST_VC02        36 non-null float64
# HC01_EST_VC03        36 non-null float64
# HC02_EST_VC03        36 non-null float64
# HC03_EST_VC03        36 non-null float64
# HC01_EST_VC06        36 non-null float64
# HC02_EST_VC06        36 non-null float64
# HC03_EST_VC06        36 non-null float64
# HC01_EST_VC25        36 non-null int64
# HC02_EST_VC25        36 non-null int64
# HC03_EST_VC25        36 non-null int64
# AH_1                 36 non-null int64
# AH_2                 36 non-null int64
# AH_3                 36 non-null int64
# AH_4                 36 non-null float64
# AH_5                 36 non-null float64
# ...

# %%
hunger_2013.columns = [header_snap_mapping.get(k,k) for k in hunger_2013.columns]

# %%
hunger_2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 21 columns):
# oregon_county                                  36 non-null object
# total_households                               36 non-null int64
# total_households_receiving_snap                36 non-null int64
# total_households_not_receiving_snap            36 non-null int64
# one_or_more_over_60                            36 non-null float64
# one_or_more_over_60_receiving_snap             36 non-null float64
# one_or_more_over_60_not_receiving_snap         36 non-null float64
# with_children_under_18                         36 non-null float64
# with_children_under_18_receiving_snap          36 non-null float64
# with_children_under_18_not_receiving_snap      36 non-null float64
# below_poverty_level                            36 non-null float64
# below_poverty_level_receiving_snap             36 non-null float64
# below_poverty_level_not_receiving_snap         36 non-null float64
# ...

# %%
sns.barplot('total_food_insecurity','oregon_county', data=hunger_2013)

# %%
sns.barplot('total_households_receiving_snap','oregon_county', data=hunger_2013)

# %%
sns.barplot('percent_food_insecurity','oregon_county', data=hunger_2013)

# %%
sns.barplot('percent_receiving_SNAP','oregon_county', data=hunger_2013)

# %%
sns.barplot('household_median_income','oregon_county', data=hunger_2013)

# %%
sns.barplot('one_or_more_over_60_receiving_snap','oregon_county', data=hunger_2013)

# %%
sns.barplot('with_children_under_18_receiving_snap','oregon_county', data=hunger_2013)

# %%
sns.barplot('one_or_more_over_60','oregon_county', data=hunger_2013)

# %%
sns.barplot('with_children_under_18','oregon_county', data=hunger_2013)
